# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r'C:\Users\tanuj\Downloads\archive(3)\heart.csv')
df.sample(10)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp
# 124   39    0   2      94   199    0        1       179     0      0.0    2  \
# 283   40    1   0     152   223    0        1       181     0      0.0    2
# 251   43    1   0     132   247    1        0       143     1      0.1    1
# 33    54    1   2     125   273    0        0       152     0      0.5    0
# 114   55    1   1     130   262    0        1       155     0      0.0    2
# 113   43    1   0     110   211    0        1       161     0      0.0    2
# 243   57    1   0     152   274    0        1        88     1      1.2    1
# 5     57    1   0     140   192    0        1       148     0      0.4    1
# 252   62    0   0     138   294    1        1       106     0      1.9    1
# 212   39    1   0     118   219    0        1       140     0      1.2    1
#
#      caa  thall  output
# 124    0      2       1
# 283    0      3       0
# 251    4      3       0
# 33     1      2       1
# 114    0      2       1
# 113    0      3       1
# 243    1      3       0
# 5      0      1       1
# 252    3      2       0
# 212    0      3       0

# %%
# check the dataset shape
print("Number of Columns in data",df.shape[1])
print("---------------------------------------")
print("Number of Rows in data",df.shape[0])
# Out:
# Number of Columns in data 14
# ---------------------------------------
# Number of Rows in data 303

# %%
# data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#CHECKING for duplicates

df.duplicated().sum()
# Out:
# 1

# %%
#removing duplicate data

df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# checking count the number of unique values in each column of the data
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trtbps       49
# chol        152
# fbs           2
# restecg       3
# thalachh     91
# exng          2
# oldpeak      40
# slp           3
# caa           5
# thall         4
# output        2
# dtype: int64

# %%
# Descriptive analysis for numerical data
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_d203e_row0_col0, #T_d203e_row0_col1, #T_d203e_row0_col2, #T_d203e_row0_col3, #T_d203e_row0_col5, #T_d203e_row0_col6, #T_d203e_row0_col7, #T_d203e_row0_col8, #T_d203e_row0_col9, #T_d203e_row0_col10, #T_d203e_row0_col11, #T_d203e_row0_col12, #T_d203e_row0_col13, #T_d203e_row7_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d203e_row0_col4 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_d203e_row1_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_d203e_row1_col1, #T_d203e_row1_col2, #T_d203e_row1_col5, #T_d203e_row1_col6, #T_d203e_row1_col8, #T_d203e_row1_col9, #T_d203e_row1_col11, #T_d203e_row1_col13, #T_d203e_row2_col0, #T_d203e_row2_col1, #T_d203e_row2_col2, #T_d203e_row2_col3, #T_d203e_row2_col4, #T_d203e_row2_col5, #T_d203e_row2_col6, #T_d203e_row2_col7, #T_d203e_row2_col8, #T_d203e_row2_col9, #T_d203e_row2_col10, #T_d203e_row2_col11, #T_d203e_row2_col12, #T_d203e_row2_col13, #T_d203e_row3_col1, #T_d203e_row3_col2, #T_d203e_row3_col5, #T_d203e_row3_col6, #T_d203e_row3_col8, #T_d203e_row3_col9, #T_d203e_row3_col10, #T_d203e_row3_col11, #T_d203e_row3_col12, #T_d203e_row3_col13, #T_d203e_row4_col1, #T_d203e_row4_col2, #T_d203e_row4_col5, #T_d203e_row4_col6, #T_d203e_row4_col8, #T_d203e_row4_col9, #T_d203e_row4_col10, #T_d203e_row4_col11, #T_d203e_row4_col13, #T_d203e_row5_col1, #T_d203e_row5_col2, #T_d203e_row5_col5, #T_d203e_row5_col6, #T_d203e_row5_col8, #T_d203e_row5_col9, #T_d203e_row5_col10, #T_d203e_row5_col11, #T_d203e_row5_col13, #T_d203e_row6_col1, #T_d203e_row6_col5, #T_d203e_row6_col6, #T_d203e_row6_col8, #T_d203e_row6_col11, #T_d203e_row6_col13, #T_d203e_row7_col1, #T_d203e_row7_col5, #T_d203e_row7_col8, #T_d203e_row7_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d203e_row1_col3 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_d203e_row1_col4 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_d203e_row1_col7 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_d203e_row1_col10, #T_d203e_row1_col12, #T_d203e_row4_col12, #T_d203e_row5_col12, #T_d203e_row6_col2, #T_d203e_row6_col9, #T_d203e_row6_col10, #T_d203e_row7_col6, #T_d203e_row7_col10 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_d203e_row3_col0 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_d203e_row3_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_d203e_row3_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_d203e_row3_col7 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_d203e_row4_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_d203e_row4_col3 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_d203e_row4_col4 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_d203e_row4_col7, #T_d203e_row5_col3 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_d203e_row5_col0 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_d203e_row5_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_d203e_row5_col7 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_d203e_row6_col0 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_d203e_row6_col3 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_d203e_row6_col4 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_d203e_row6_col7 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_d203e_row6_col12, #T_d203e_row7_col2, #T_d203e_row7_col12 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_d203e_row7_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_d203e_row7_col3, #T_d203e_row7_col7 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_d203e_row7_col9 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_d203e_row7_col11 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_d203e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d203e_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_d203e_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_d203e_level0_col2" class="col_heading level0 col2" >cp</th>
#       <th id="T_d203e_level0_col3" class="col_heading level0 col3" >trtbps</th>
#       <th id="T_d203e_level0_col4" class="col_heading level0 col4" >chol</th>
#       <th id="T_d203e_level0_col5" class="col_heading level0 col5" >fbs</th>
#       <th id="T_d203e_level0_col6" class="col_heading level0 col6" >restecg</th>
#       <th id="T_d203e_level0_col7" class="col_heading level0 col7" >thalachh</th>
#       <th id="T_d203e_level0_col8" class="col_heading level0 col8" >exng</th>
#       <th id="T_d203e_level0_col9" class="col_heading level0 col9" >oldpeak</th>
#       <th id="T_d203e_level0_col10" class="col_heading level0 col10" >slp</th>
#       <th id="T_d203e_level0_col11" class="col_heading level0 col11" >caa</th>
#       <th id="T_d203e_level0_col12" class="col_heading level0 col12" >thall</th>
#       <th id="T_d203e_level0_col13" class="col_heading level0 col13" >output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d203e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_d203e_row0_col0" class="data row0 col0" >302.000000</td>
#       <td id="T_d203e_row0_col1" class="data row0 col1" >302.000000</td>
#       <td id="T_d203e_row0_col2" class="data row0 col2" >302.000000</td>
#       <td id="T_d203e_row0_col3" class="data row0 col3" >302.000000</td>
#       <td id="T_d203e_row0_col4" class="data row0 col4" >302.000000</td>
#       <td id="T_d203e_row0_col5" class="data row0 col5" >302.000000</td>
#       <td id="T_d203e_row0_col6" class="data row0 col6" >302.000000</td>
#       <td id="T_d203e_row0_col7" class="data row0 col7" >302.000000</td>
#       <td id="T_d203e_row0_col8" class="data row0 col8" >302.000000</td>
#       <td id="T_d203e_row0_col9" class="data row0 col9" >302.000000</td>
#       <td id="T_d203e_row0_col10" class="data row0 col10" >302.000000</td>
#       <td id="T_d203e_row0_col11" class="data row0 col11" >302.000000</td>
#       <td id="T_d203e_row0_col12" class="data row0 col12" >302.000000</td>
#       <td id="T_d203e_row0_col13" class="data row0 col13" >302.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d203e_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_d203e_row1_col0" class="data row1 col0" >54.420530</td>
#       <td id="T_d203e_row1_col1" class="data row1 col1" >0.682119</td>
#       <td id="T_d203e_row1_col2" class="data row1 col2" >0.963576</td>
#       <td id="T_d203e_row1_col3" class="data row1 col3" >131.602649</td>
#       <td id="T_d203e_row1_col4" class="data row1 col4" >246.500000</td>
#       <td id="T_d203e_row1_col5" class="data row1 col5" >0.149007</td>
#       <td id="T_d203e_row1_col6" class="data row1 col6" >0.526490</td>
#       <td id="T_d203e_row1_col7" class="data row1 col7" >149.569536</td>
#       <td id="T_d203e_row1_col8" class="data row1 col8" >0.327815</td>
#       <td id="T_d203e_row1_col9" class="data row1 col9" >1.043046</td>
#       <td id="T_d203e_row1_col10" class="data row1 col10" >1.397351</td>
#       <td id="T_d203e_row1_col11" class="data row1 col11" >0.718543</td>
#       <td id="T_d203e_row1_col12" class="data row1 col12" >2.314570</td>
#       <td id="T_d203e_row1_col13" class="data row1 col13" >0.543046</td>
#     </tr>
#     <tr>
#       <th id="T_d203e_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_d203e_row2_col0" class="data row2 col0" >9.047970</td>
#       <td id="T_d203e_row2_col1" class="data row2 col1" >0.466426</td>
#       <td id="T_d203e_row2_col2" class="data row2 col2" >1.032044</td>
#       <td id="T_d203e_row2_col3" class="data row2 col3" >17.563394</td>
#       <td id="T_d203e_row2_col4" class="data row2 col4" >51.753489</td>
#       <td id="T_d203e_row2_col5" class="data row2 col5" >0.356686</td>
#       <td id="T_d203e_row2_col6" class="data row2 col6" >0.526027</td>
#       <td id="T_d203e_row2_col7" class="data row2 col7" >22.903527</td>
#       <td id="T_d203e_row2_col8" class="data row2 col8" >0.470196</td>
#       <td id="T_d203e_row2_col9" class="data row2 col9" >1.161452</td>
#       <td id="T_d203e_row2_col10" class

# %% [markdown]
# # Data Preprocessing

# %%
# checking for missing values in data
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
# First we extract the x Featues and y Label
x = df.drop(['output'], axis=1)
y = df['output']

# %%
x.shape, y.shape
# Out:
# ((302, 13), (302,))

# %%
# Then we Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(x, 
                                                    y, 
                                                    test_size = 0.2, 
                                                    random_state = 0)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 241 samples.
# Testing set has 61 samples.

# %% [markdown]
# # Feature Scaling using Normalization

# %%
from sklearn.preprocessing import Normalizer

# %%
cont_features = ['age', 'trtbps', 'chol', 'thalachh', 'oldpeak']

# Creating a StandardScaler instance
scaler = Normalizer()

# Fitting the StandardScaler on the training data
scaler.fit(X_train[cont_features])

# Transforming (standardize) the continuous features in the training and testing data
X_train_cont_scaled = scaler.transform(X_train[cont_features])
X_test_cont_scaled = scaler.transform(X_test[cont_features])

# Replacing the scaled continuous features in the original data
X_train[cont_features] = X_train_cont_scaled
X_test[cont_features] = X_test_cont_scaled

X_train
# Out:
#           age  sex  cp    trtbps      chol  fbs  restecg  thalachh  exng
# 74   0.143872    0   2  0.408196  0.712669    0        1  0.552068     0  \
# 153  0.185890    0   2  0.411211  0.782990    0        0  0.428110     0
# 64   0.188465    1   2  0.454915  0.685622    1        0  0.536150     0
# 296  0.227554    0   0  0.447884  0.711558    0        1  0.491228     1
# 288  0.148148    1   0  0.285900  0.870697    0        1  0.371671     1
# ..        ...  ...  ..       ...       ...  ...      ...       ...   ...
# 252  0.178560    0   0  0.397439  0.846719    1        1  0.305280     0
# 193  0.170169    1   0  0.411241  0.799792    0        0  0.402732     1
# 117  0.196724    1   3  0.421552  0.677996    0        0  0.569095     0
# 47   0.140667    1   2  0.413022  0.769178    0        0  0.466894     0
# 173  0.182589    1   2  0.415548  0.705173    0        0  0.544620     0
#
#       oldpeak  slp  caa  thall
# 74   0.000669    1    0      2
# 153  0.000000    1    1      2
# 64   0.000000    2    0      2
# 296  0.000000    1    0      2
# 288  0.007797    1    1      3
# ..        ...  ...  ...    ...
# 252  0.005472    1    3      2
# 193  0.007941    1    2      3
# 117  0.006675    1    0      3
# 47   0.000000    2    0      2
# 173  0.010074    2    2      3
#
# [241 rows x 13 columns]

# %%
fig, axes = plt.subplots(3, 3, figsize=(13, 9))
# Creating a list of categorical features 
cat_features = ['age','sex', 'cp', 'fbs', 'restecg', 'exng', 'slp', 'caa', 'thall', 'output']

#Looping through the subplots and create countplots for each feature
for i, ax in enumerate(axes.flat):
    if i < len(cat_features):
        sns.countplot(data=df, x=cat_features[i], ax=ax, palette='Set2', orient='h')
        ax.set_title(f'Countplot for {cat_features[i]}', fontsize=14)
        
# Adjusting the layout for better visualization
plt.tight_layout()

plt.show()
